# %% [markdown]
# # Geopandas
#
#
#
# ### Attawut Nardkulpat, Reseach Officer, Burapha University
# ### Reference: https://github.com/jorisvandenbossche/geopandas-tutorial
# ### attawut@buu.ac.th
# ### 09/11/2021

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# # Part 1 Introduction to geospatial vector data in Python

# %% [markdown]
# ## Install Geopandas

# %%
#!pip install geopandas
#!pip install matplotlib
#!pip install pandas
#!pip install shapely

# %%
#conda install -c conda-forge geopandas

# %% [markdown]
# ## Import Geopandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ## Importing geospatial data
# Geospatial data is often available from specific GIS file formats or data stores, like ESRI shapefiles, GeoJSON files, geopackage files, PostGIS (PostgreSQL) database, ...
#
# We can use the GeoPandas library to read many of those GIS file formats (relying on the fiona library under the hood, which is an interface to GDAL/OGR), using the geopandas.read_file function.

# %%
countries = gpd.read_file("data/ne_110m_admin_0_countries.shp")

# %%
countries.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise 1
# สร้างตัวแปร BUU_point, BUU_line และ BUU_polygon

# %%
BUU_point = gpd.read_file("data/Building_BUU_point_wgs84.shp")
BUU_line = gpd.read_file("data/Road_BUU_wgs84.shp")
BUU_polygon = gpd.read_file("data/Boundary_BUU_wgs84.shp")

# %% [markdown]
# แสดงผลข้อมูล

# %%
BUU_point.plot()
BUU_line.plot()
BUU_polygon.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ดูหัวตารางของแต่ข้อมูล

# %%
BUU_point.head()
# Out:
#    Id                             Name                          Serviceare  \
# 0   1      หอศิลปวัฒนธรรม  ภาคตะวันออก                          02.ลานธรรม
# 1   2           อาคารเรียนรวม KA,KB.KC                          02.ลานธรรม
# 2   3  โครงการก่อสร้างศูนย์การเรียนรู้  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
# 3   4               อาคารเรียนคณะเภสัช  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
# 4   5                   คณะเภสัชศาสตร์  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
#
#                            Name_order  Servicenum         Area      Type  \
# 0      1. หอศิลปวัฒนธรรม  ภาคตะวันออก           2  4254.197720  Building
# 1           2. อาคารเรียนรวม KA,KB.KC           2  6531.489408  Building
# 2  3. โครงการก่อสร้างศูนย์การเรียนรู้           8  2562.547955  Building
# 3               4. อาคารเรียนคณะเภสัช           8  3055.459077  Building
# 4                   5. คณะเภสัชศาสตร์           8   725.140707  Building
#
#    ORIG_FID                    geometry
# 0         0  POINT (100.92597 13.28501)
# 1         1  POINT (100.92708 13.28363)
# 2         2  POINT (100.92653 13.28248)
# 3         3  POINT (100.92660 13.28163)
# 4         4  POINT (100.92708 13.28149)

# %%
BUU_line.head()
# Out:
#       osm_id  code       fclass  name   ref oneway  maxspeed  layer bridge  \
# 0  154653502  5141      service  None  None      B         0    0.0      F
# 1  154653503  5141      service  None  None      B         0    0.0      F
# 2  154653504  5122  residential  None  None      B         0    0.0      F
# 3  154653505  5122  residential  None  None      B         0    0.0      F
# 4  154653506  5122  residential  None  None      B         0    0.0      F
#
#   tunnel      Lenght                                           geometry
# 0      F   65.703677  LINESTRING (100.92459 13.27616, 100.92456 13.2...
# 1      F  101.572195  LINESTRING (100.92440 13.27655, 100.92533 13.2...
# 2      F  485.426263  LINESTRING (100.92373 13.28318, 100.92383 13.2...
# 3      F  615.042666  LINESTRING (100.92861 13.27325, 100.92837 13.2...
# 4      F  848.986408  LINESTRING (100.92706 13.27761, 100.92718 13.2...

# %%
BUU_polygon.head()
# Out:
#    Id          area     arearai                Name  \
# 0   0  1.004277e+06  627.673338  Burapha University
#
#                                             geometry
# 0  POLYGON ((100.92146 13.28532, 100.92189 13.285...

# %% [markdown]
# ----------------------

# %% [markdown]
#  ## GeoDataFrame

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
countries.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
type(countries.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
countries.geometry.area
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# 0         1.639511
# 1        76.301964
# 2         8.603984
# 3      1712.995228
# 4      1122.281921
#           ...
# 172       8.604719
# 173       1.479321
# 174       1.231641
# 175       0.639000
# 176      51.196106
# Length: 177, dtype: float64

# %%
countries['POP_EST'].mean()
# Out:
# 41712369.84180791

# %%
africa = countries[countries['CONTINENT'] == 'Africa']

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ตรวจสอบประเภทตัวแปรที่นิสิตสร้างขึ้น

# %%
type(BUU_point)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# หาค่าเฉลี่ยของพื้นที่อาคาร

# %%
BUU_point['Area'].mean()
# Out:
# 1386.2756741908001

# %% [markdown]
# ทำการเลือกเฉพาะข้อมูลถนนใน column fclass = residential

# %%
BUU_line_residential = BUU_line[BUU_line['fclass'] == 'residential']

# %%
BUU_line_residential
# Out:
#        osm_id  code       fclass     name   ref oneway  maxspeed  layer  \
# 2   154653504  5122  residential     None  None      B         0    0.0
# 3   154653505  5122  residential     None  None      B         0    0.0
# 4   154653506  5122  residential     None  None      B         0    0.0
# 5   154653507  5122  residential     None  None      B         0    0.0
# 6   154653508  5122  residential     None  None      B         0    0.0
# 7   154653509  5122  residential     None  None      B         0    0.0
# 9   154653511  5122  residential     None  None      B         0    0.0
# 10  154653512  5122  residential     None  None      B         0    0.0
# 12  154653514  5122  residential     None  None      B         0    0.0
# 13  154653515  5122  residential     None  None      B         0    0.0
# 14  154653516  5122  residential     None  None      B         0    0.0
# 16  154653518  5122  residential     None  None      B         0    0.0
# 20  154653522  5122  residential     None  None      B         0    0.0
# 22  154653524  5122  residential     None  None      B         0    0.0
# 24  154653526  5122  residential     None  None      B         0    0.0
# 25  154653527  5122  residential     None  None      B         0    0.0
# 26  154653528  5122  residential     None  None      B         0    0.0
# 27  154653529  5122  residential     None  None      B         0    0.0
# 28  154653753  5122  residential     None  None      B         0    0.0
# 29  154653755  5122  residential     None  None      B         0    0.0
# 30  154653778  5122  residential     None  None      F         0    0.0
# 32  154654024  5122  residential     None  None      F         0    0.0
# 33  154654025  5122  residential     None  None      B         0    0.0
# 34  154654026  5122  residential     None  None      B         0    0.0
# 35  154654027  5122  residential     None  None      B         0    0.0
# 36  154654028  5122  residential  ซอยสดใส  None      B         0    0.0
# 37  154654029  5122  residential     None  None      B         0    0.0
# 38  154654030  5122  residential     None  None      B         0    0.0
# 39  154654031  5122  residential     None  None      B         0    0.0
# 46  352736543  5122  residential  ซอยลีลา  None      B         0    0.0
# 48  362726286  5122  residential     None  None      B         0    0.0
# 49  362726287  5122  residential     None  None      B         0    0.0
# 50  362726288  5122  residential     None  None      B         0    0.0
# 51  362726289  5122  residential     None  None      B         0    0.0
# 52  362726290  5122  residential     None  None      B         0    0.0
# 53  362726291  5122  residential     None  None      B         0    0.0
# 57  362726295  5122  residential     None  None      B         0    0.0
# 62  694840111  5122  residential     None  None      B         0    0.0
# 64  695668745  5122  residential     None  None      F         0    0.0
# 65  695668746  5122  residential     None  None      F         0    0.0
# 66  695668747  5122  residential  ซอยสดใส  None      B         0    0.0
# 67  695668748  5122  residential  ซอยสดใส  None      B         0    0.0
# 68  695669055  5122  residential     None  None      B         0    0.0
# 69  695669056  5122  residential     None  None      B         0    0.0
#
#    bridge tunnel      Lenght  \
# 2       F      F  485.426263
# 3       F      F  615.042666
# 4       F      F  848.986408
# 5       F      F   68.051048
# 6       F      F   39.473363
# 7       F      F   69.574691
# 9       F      F  114.056603
# 10      F      F  168.519711
# 12      F      F  793.589278
# 13      F      F  123.166219
# 14      F      F  123.748646
# 16      F      F  261.551650
# 20      F      F  190.955076
# 22      F      F  109.919318
# 24      F      F  196.020972
# 25      F      F   65.862455
# 26      F      F   67.954932
# 27      F      F  193.600370
# 28      F      F  279.606354
# 29      F      F  265.265754
# 30      F      F  554.136147
# 32      F      F  551.779846
# 33      F      F  152.430078
# 34      F      F  111.903025
# 35      F      F  242.343050
# 36      F      F  120.680868
# 37      F      F   11.538736
# 38      F      F  215.414403
# 39      F      F  216.514548
# 46      F      F   77.710287
# 48      F      F  186.179722
# 49      F      F   32.243865
# 50      F      F    7.070357
# 51      F      F    7.838765
# 52      F      F  203.787654
# 53      F      F  207.822931
# 57      F      F  104.459617
# 62      F      F  148.380323
# 64      F      F    8.614274
# 65      F      F   17.974519
# 66      F      F   10.382243
# 67      F      F  160.669833
# 68      F      F  269.332055
# 69      F      F  159.570338
#
#                                              geometry
# 2   LINESTRING (100.92373 13.28318, 100.92383 13.2...
# 3   LINESTRING (100.92861 13.27325, 100.92837 13.2...
# 4   LINESTRING (100.92706 13.27761, 100.92718 13.2...
# 5   LINESTRING (100.92645 13.27954, 100.92646 13.2...
# 6   LINESTRING (100.92394 13.27852, 100.92394 13.2...
# 7   LINESTRING (100.92464 13.27876, 100.92461 13.2...
# 9   LINESTRING (100.92717 13.27146, 100.92726 13.2...
# 10  LINESTRING (100.92686 13.27637, 100.92631 13.2...
# 12  LINESTRING (100.92194 13.28541, 100.92207 13.2...
# 13  LINESTRING (100.92776 13.27141, 100.92717 13.2...
# 14  LINESTRING (100.92784 13.27244, 100.92726 13.2...
# 16  LINESTRING (100.92477 13.27878, 100.92582 13.2...
# 20  LINESTRING (100.92458 13.27691, 100.92446 13.2...
# 22  LINESTRING (100.92458 13.27691, 100.92473 13.2...
# 24  LINESTRING (100.92694 13.27770, 100.92658 13.2...
# 25  LINESTRING (100.92405 13.27855, 100.92461 13.2...
# 26  LINESTRING (100.92687 13.27764, 100.92689 13.2...
# 27  LINESTRING (100.92646 13.27951, 100.92479 13.2...
# 28  LINESTRING (100.92373 13.28318, 100.92377 13.2...
# 29  LINESTRING (100.92170 13.27756, 100.92240 13.2...
# 30  LINESTRING (100.92632 13.28121, 100.92622 13.2...
# 32  LINESTRING (100.92538 13.28604, 100.92541 13.2...
# 33  LINESTRING (100.92408 13.28213, 100.92270 13.2...
# 34  LINESTRING (100.92454 13.28212, 100.92448 13.2...
# 35  LINESTRING (100.92716 13.27975, 100.92719 13.2...
# 36  LINESTRING (100.92751 13.28127, 100.92748 13.2...
# 37  LINESTRING (100.92634 13.28107, 100.92630 13.2...
.9295120959971 13.27893318702336, 100.9289978878579 13.27886042209442, 100.9285770873192 13.27880087433245, 100.9285776311659 13.27862419748338, 100.9285844815732 13.27855183313494, 100.9285975621937 13.27837803111265, 100.9287866842168 13.27838578088912, 100.9292560486466 13.27846410201864, 100.929291918966 13.27829986462892, 100.9293333504697 13.27809294371919, 100.9293567744149 13.27797999325633, 100.9293866188303 13.27782682056714, 100.9293488217756 13.27767789087941, 100.9293440122236 13.27766243180597, 100.9293081735268 13.27746470506813, 100.929307308936 13.2774005047542, 100.9292845275492 13.27740118044168, 100.9292594094211 13.27731941668552, 100.9292329389069 13.27727537850652, 100.9291933992592 13.27712010115478, 100.9291760344746 13.27702343354003, 100.9291652244792 13.27691590765132, 100.929164894244 13.27683699776925, 100.9291754949198 13.27669544906531, 100.9291992623181 13.27655179192021, 100.9292165446866 13.27648184638711, 100.9292400711647 13.2763762109744, 100.9292721496656 13.27624735524198, 100.9292887513688 13.27616085626069, 100.929293864113 13.27610342669741, 100.9292897669881 13.27599269345014, 100.9292816201355 13.27592560791276, 100.9292730890788 13.27588406420268, 100.9292773433884 13.27582922373023, 100.9292753228529 13.27579595236041, 100.92930 ...

# %% [markdown]
# ## Plotting our different layers together

# %%
ax = BUU_polygon.plot(figsize=(50, 50))
BUU_point.plot(ax=ax, color='red')
BUU_line.plot(ax=ax,color='yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# -----------

# %% [markdown]
# # Part 2 Coordinate reference systems

# %% [markdown]
# ### Projected coordinates
#
# > `(x, y)` coordinates are usually in meters or feet
#
# ![](img/projection.png)
#
# <table><tr>
# <td> <img src="img/projections-AlbersEqualArea.png"/> </td>
# <td> <img src="img/projections-Mercator.png"/> </td>
# </tr>
# <tr>
# <td> <img src="img/projections-Robinson.png"/> </td>
# </tr></table>
#
# **Projected size vs actual size (Mercator projection)**:
#
# ![](img/mercator_projection_area.gif)

# %% [markdown]
# ## Coordinate Reference Systems in Python / GeoPandas

# %% [markdown]
# The `.crs` attribute is given as a dictionary. In this case, it only indicates the EPSG code, but it can also contain the full "proj4" string (in dictionary form).
#
# Possible CRS representation:
#
# - **`proj4` string**
#
#   Example: `+proj=longlat +datum=WGS84 +no_defs`
#
#   Or its dict representation: `{'proj': 'longlat', 'datum': 'WGS84', 'no_defs': True}`
#
# - **EPSG code**
#
#   Example: `EPSG:4326` = WGS84 geographic CRS (longitude, latitude)
#
# - Well-Know-Text (WKT) representation (better support coming with PROJ6 in the next GeoPandas version)
#
# See eg https://epsg.io/4326
#
# Under the hood, GeoPandas uses the `pyproj` / `PROJ` libraries to deal with the re-projections.
#
# For more information, see also http://geopandas.readthedocs.io/en/latest/projections.html.

# %%
countries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
countries.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise 4
# เช็ค Coordinate Reference System ของข้อมูล

# %%
BUU_point.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Transforming to another CRS

# %%
# remove Antartica, as the Mercator projection cannot deal with the poles
countries = countries[(countries['NAME'] != "Antarctica")]

# %%
countries_mercator = countries.to_crs({'init': 'epsg:3395'})
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
countries_mercator.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise 5
# แปลงระบบพิกัดของข้อมูลจาก WGS84 Geographic Coordinate เป็น WGS84 UTM Zone 47N

# %%
BUU_point_UTM47N = BUU_point.to_crs({'init': 'epsg:32647'})
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
BUU_point.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
BUU_point_UTM47N.crs
# Out:
# <Projected CRS: EPSG:32647>
# Name: WGS 84 / UTM zone 47N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - N hemisphere - 96°E to 102°E - by country
# - bounds: (96.0, 0.0, 102.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 47N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Writing files
# VARIABLE.to_file("NAME.shp")

# %%
BUU_point_UTM47N.to_file("BUU_point_UTM47N.shp")

# %% [markdown]
# ----------------

# %% [markdown]
# # Part 3 Spatial relationships and operations

# %%
countries = gpd.read_file("zip://./data/ne_110m_admin_0_countries.zip")
cities = gpd.read_file("zip://./data/ne_110m_populated_places.zip")
rivers = gpd.read_file("zip://./data/ne_50m_rivers_lake_centerlines.zip")

# %% [markdown]
# ## Spatial relationships
#
# ![](img/TopologicSpatialRelarions2.png)
#
# (Image by [Krauss, CC BY-SA 3.0](https://en.wikipedia.org/wiki/Spatial_relation#/media/File:TopologicSpatialRelarions2.png))

# %% [markdown]
# ### Relationships between individual objects

# %% [markdown]
# A polygon <small>(note: we use `.squeeze()` here to to extract the scalar geometry object from the GeoSeries of length 1)</small>:

# %%
belgium = countries.loc[countries['name'] == 'Belgium', 'geometry'].squeeze()

# %%
#2 Points
paris = cities.loc[cities['name'] == 'Paris', 'geometry'].squeeze()
brussels = cities.loc[cities['name'] == 'Brussels', 'geometry'].squeeze()

# %%
from shapely.geometry import LineString
line = LineString([paris, brussels])

# %%
gpd.GeoSeries([belgium, paris, brussels, line]).plot(cmap='tab10')
# Out:
# <AxesSubplot:>

# %%
brussels.within(belgium)
# Out:
# True

# %%
belgium.contains(brussels)
# Out:
# True

# %%
belgium.contains(paris)
# Out:
# False

# %%
paris.within(belgium)
# Out:
# False

# %%
belgium.contains(line)
# Out:
# False

# %%
line.intersects(belgium)
# Out:
# True

# %% [markdown]
# ## Exercise 6
# เช็คความสัมพันธ์ของข้อมูล

# %%
BUU_point.within(BUU_polygon)
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Length: 187, dtype: bool

# %%
BUU_point.contains(BUU_polygon)
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Length: 187, dtype: bool

# %%
BUU_point.intersects(BUU_polygon)
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Length: 187, dtype: bool

# %% [markdown]
# ## Spatial operations

# %% [markdown]
# **Binary operations:**
#
# <table><tr>
# <td> <img src="img/spatial-operations-base.png"/> </td>
# <td> <img src="img/spatial-operations-intersection.png"/> </td>
# </tr>
# <tr>
# <td> <img src="img/spatial-operations-union.png"/> </td>
# <td> <img src="img/spatial-operations-difference.png"/> </td>
# </tr></table>
#
# **Buffer:**
#
# <table><tr>
# <td> <img src="img/spatial-operations-buffer-point1.png"/> </td>
# <td> <img src="img/spatial-operations-buffer-point2.png"/> </td>
# </tr>
# <tr>
# <td> <img src="img/spatial-operations-buffer-line.png"/> </td>
# <td> <img src="img/spatial-operations-buffer-polygon.png"/> </td>
# </tr></table>
#
#
# See https://shapely.readthedocs.io/en/stable/manual.html#spatial-analysis-methods for more details.

# %% [markdown]
# ### Buffer

# %%
gpd.GeoSeries([brussels.buffer(1)]).plot(alpha=0.5, cmap='tab10')
# Out:
# <AxesSubplot:>

# %%
gpd.GeoSeries([belgium, brussels.buffer(1)]).plot(alpha=0.5, cmap='tab10')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Intersection

# %%
brussels.buffer(1).intersection(belgium)

# %% [markdown]
# ### union

# %%
brussels.buffer(1).union(belgium)

# %% [markdown]
# ### difference

# %%
brussels.buffer(1).difference(belgium)

# %% [markdown]
# ## Exercise 7
# ให้นิสิตทดลองทำ Buffer, Union, Intersction กับข้อมูล

# %%
BUU_line.plot()
# Out:
# <AxesSubplot:>

# %%
BUU_line.buffer(0.0003,resolution = 1).plot()
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:>

# %%
BUU_point.union(BUU_line).plot()
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# <AxesSubplot:>

# %% [markdown]
# -----------

# %% [markdown]
# # Part 4 Spatial joins

# %%
cities2 = cities[cities['name'].isin(['Bern', 'Brussels', 'London', 'Paris'])].copy()
cities2['iso_a3'] = ['CHE', 'BEL', 'GBR', 'FRA']

# %%
cities2
# Out:
#          name                   geometry iso_a3
# 26       Bern   POINT (7.46698 46.91668)    CHE
# 170  Brussels   POINT (4.33137 50.83526)    BEL
# 219    London  POINT (-0.11867 51.50194)    GBR
# 235     Paris   POINT (2.33139 48.86864)    FRA

# %%
countries2 = countries[['iso_a3', 'name', 'continent']]
countries2.head()
# Out:
#   iso_a3                  name      continent
# 0    AFG           Afghanistan           Asia
# 1    AGO                Angola         Africa
# 2    ALB               Albania         Europe
# 3    ARE  United Arab Emirates           Asia
# 4    ARG             Argentina  South America

# %%
cities2.merge(countries2, on='iso_a3')
# Out:
#      name_x                   geometry iso_a3          name_y continent
# 0      Bern   POINT (7.46698 46.91668)    CHE     Switzerland    Europe
# 1  Brussels   POINT (4.33137 50.83526)    BEL         Belgium    Europe
# 2    London  POINT (-0.11867 51.50194)    GBR  United Kingdom    Europe
# 3     Paris   POINT (2.33139 48.86864)    FRA          France    Europe

# %% [markdown]
# ## Recap - spatial relationships between objects

# %%
france = countries.loc[countries['name'] == 'France', 'geometry'].squeeze()

# %%
cities.within(france)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# Length: 243, dtype: bool

# %%
cities[cities.within(france)]
# Out:
#         name                  geometry
# 10    Monaco  POINT (7.40691 43.73965)
# 13   Andorra  POINT (1.51649 42.50000)
# 186   Geneva  POINT (6.14003 46.21001)
# 235    Paris  POINT (2.33139 48.86864)

# %% [markdown]
# ## Spatial join operation
#
# <div class="alert alert-info" style="font-size:120%">
#
# **SPATIAL JOIN** = *transferring attributes from one layer to another based on their spatial relationship* <br>
# ​
# ​
# Different parts of this operations:
# ​
# * The GeoDataFrame to which we want add information
# * The GeoDataFrame that contains the information we want to add
# * The spatial relationship we want to use to match both datasets ('intersects', 'contains', 'within')
# * The type of join: left or inner join
# ​
# ​
# ![](img/illustration-spatial-join.svg)
# ​
# </div>

# %%
joined = gpd.sjoin(cities, countries, op='within', how='left')

# %%
joined
# Out:
#           name_left                     geometry  index_right iso_a3  \
# 0      Vatican City    POINT (12.45339 41.90328)         79.0    ITA
# 1        San Marino    POINT (12.44177 43.93610)         79.0    ITA
# 2             Vaduz     POINT (9.51667 47.13372)          9.0    AUT
# 3           Lobamba   POINT (31.20000 -26.46667)        152.0    SWZ
# 4        Luxembourg     POINT (6.13000 49.61166)         97.0    LUX
# ..              ...                          ...          ...    ...
# 238  Rio de Janeiro  POINT (-43.22697 -22.92308)         22.0    BRA
# 239       São Paulo  POINT (-46.62697 -23.55673)         22.0    BRA
# 240          Sydney  POINT (151.18323 -33.91807)          8.0    AUS
# 241       Singapore    POINT (103.85387 1.29498)        111.0    MYS
# 242       Hong Kong   POINT (114.18306 22.30693)         30.0    CHN
#
#      name_right      continent       pop_est  gdp_md_est
# 0         Italy         Europe  6.213780e+07   2221000.0
# 1         Italy         Europe  6.213780e+07   2221000.0
# 2       Austria         Europe  8.754413e+06    416600.0
# 3     Swaziland         Africa  1.467152e+06     11060.0
# 4    Luxembourg         Europe  5.941300e+05     58740.0
# ..          ...            ...           ...         ...
# 238      Brazil  South America  2.073534e+08   3081000.0
# 239      Brazil  South America  2.073534e+08   3081000.0
# 240   Australia        Oceania  2.323241e+07   1189000.0
# 241    Malaysia           Asia  3.138199e+07    863000.0
# 242       China           Asia  1.379303e+09  21140000.0
#
# [243 rows x 8 columns]

# %%
joined['continent'].value_counts()
# Out:
# Asia             59
# Africa           57
# Europe           46
# North America    26
# South America    14
# Oceania           8
# Name: continent, dtype: int64

# %% [markdown]
# ## Exercise 8
# ให้นิสิต Spatial Join ระหว่างข้อมูลจุดที่ตั้งอาคารกับขอบเขตมหาวิทยาลัยบูรพา

# %%
BUU_point
# Out:
#      Id                             Name                          Serviceare  \
# 0     1      หอศิลปวัฒนธรรม  ภาคตะวันออก                          02.ลานธรรม
# 1     2           อาคารเรียนรวม KA,KB.KC                          02.ลานธรรม
# 2     3  โครงการก่อสร้างศูนย์การเรียนรู้  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
# 3     4               อาคารเรียนคณะเภสัช  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
# 4     5                   คณะเภสัชศาสตร์  08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ
# ..   ..                              ...                                 ...
# 182   0                             None                                None
# 183   0                             None                                None
# 184   0                             None                                None
# 185   0                             None                                None
# 186   0                             None                                None
#
#                              Name_order  Servicenum         Area      Type  \
# 0        1. หอศิลปวัฒนธรรม  ภาคตะวันออก           2  4254.197720  Building
# 1             2. อาคารเรียนรวม KA,KB.KC           2  6531.489408  Building
# 2    3. โครงการก่อสร้างศูนย์การเรียนรู้           8  2562.547955  Building
# 3                 4. อาคารเรียนคณะเภสัช           8  3055.459077  Building
# 4                     5. คณะเภสัชศาสตร์           8   725.140707  Building
# ..                                  ...         ...          ...       ...
# 182                                None           0     8.323549  Building
# 183                                None           0    12.768843  Building
# 184                                None           0   382.512862  Building
# 185                                None           0  1046.639078  Building
# 186                                None           0     0.000000  Building
#
#      ORIG_FID                    geometry
# 0           0  POINT (100.92597 13.28501)
# 1           1  POINT (100.92708 13.28363)
# 2           2  POINT (100.92653 13.28248)
# 3           3  POINT (100.92660 13.28163)
# 4           4  POINT (100.92708 13.28149)
# ..        ...                         ...
# 182       182  POINT (100.92817 13.27654)
# 183       183  POINT (100.92816 13.27667)
# 184       184  POINT (100.92765 13.27894)
# 185       185  POINT (100.92751 13.28414)
# 186       186  POINT (100.92638 13.28422)
#
# [187 rows x 9 columns]

# %%
BUU_polygon
# Out:
#    Id          area     arearai                Name  \
# 0   0  1.004277e+06  627.673338  Burapha University
#
#                                             geometry
# 0  POLYGON ((100.92146 13.28532, 100.92189 13.285...

# %%
BUU_joined = gpd.sjoin(BUU_point,BUU_polygon , op='within', how='left')

# %%
BUU_joined
# Out:
#      Id_left                        Name_left  \
# 0          1      หอศิลปวัฒนธรรม  ภาคตะวันออก
# 1          2           อาคารเรียนรวม KA,KB.KC
# 2          3  โครงการก่อสร้างศูนย์การเรียนรู้
# 3          4               อาคารเรียนคณะเภสัช
# 4          5                   คณะเภสัชศาสตร์
# ..       ...                              ...
# 182        0                             None
# 183        0                             None
# 184        0                             None
# 185        0                             None
# 186        0                             None
#
#                              Serviceare                          Name_order  \
# 0                            02.ลานธรรม      1. หอศิลปวัฒนธรรม  ภาคตะวันออก
# 1                            02.ลานธรรม           2. อาคารเรียนรวม KA,KB.KC
# 2    08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ  3. โครงการก่อสร้างศูนย์การเรียนรู้
# 3    08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ               4. อาคารเรียนคณะเภสัช
# 4    08.สนามหญ้าหลังอาคารเรียนคณะเภสัชฯ                   5. คณะเภสัชศาสตร์
# ..                                  ...                                 ...
# 182                                None                                None
# 183                                None                                None
# 184                                None                                None
# 185                                None                                None
# 186                                None                                None
#
#      Servicenum         Area      Type  ORIG_FID                    geometry  \
# 0             2  4254.197720  Building         0  POINT (100.92597 13.28501)
# 1             2  6531.489408  Building         1  POINT (100.92708 13.28363)
# 2             8  2562.547955  Building         2  POINT (100.92653 13.28248)
# 3             8  3055.459077  Building         3  POINT (100.92660 13.28163)
# 4             8   725.140707  Building         4  POINT (100.92708 13.28149)
# ..          ...          ...       ...       ...                         ...
# 182           0     8.323549  Building       182  POINT (100.92817 13.27654)
# 183           0    12.768843  Building       183  POINT (100.92816 13.27667)
# 184           0   382.512862  Building       184  POINT (100.92765 13.27894)
# 185           0  1046.639078  Building       185  POINT (100.92751 13.28414)
# 186           0     0.000000  Building       186  POINT (100.92638 13.28422)
#
#      index_right  Id_right          area     arearai          Name_right
# 0              0         0  1.004277e+06  627.673338  Burapha University
# 1              0         0  1.004277e+06  627.673338  Burapha University
# 2              0         0  1.004277e+06  627.673338  Burapha University
# 3              0         0  1.004277e+06  627.673338  Burapha University
# 4              0         0  1.004277e+06  627.673338  Burapha University
# ..           ...       ...           ...         ...                 ...
# 182            0         0  1.004277e+06  627.673338  Burapha University
# 183            0         0  1.004277e+06  627.673338  Burapha University
# 184            0         0  1.004277e+06  627.673338  Burapha University
# 185            0         0  1.004277e+06  627.673338  Burapha University
# 186            0         0  1.004277e+06  627.673338  Burapha University
#
# [187 rows x 14 columns]

# %% [markdown]
# ## The overlay operation

# %%
africa = countries[countries['continent'] == 'Africa']

# %%
africa.plot()
# Out:
# <AxesSubplot:>

# %%
cities['geometry'] = cities.buffer(2)
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
gpd.overlay(africa, cities, how='difference').plot()
# Out:
# <AxesSubplot:>

# %%
type(cities)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ## Exercise 9
# ให้นิสิต Overlay ระหว่างข้อมูลจุดที่ตั้งอาคารกับขอบเขตมหาวิทยาลัยบูรพา

# %%
BUU_point['geometry'] = BUU_point.buffer(0.0003,resolution = 1)
# Out:
# /Users/attawutn/opt/anaconda3/envs/SWU_tech/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
BUU_point.plot()
# Out:
# <AxesSubplot:>

# %%
gpd.overlay(BUU_polygon,BUU_point, how='difference').plot()
# Out:
# <AxesSubplot:>
